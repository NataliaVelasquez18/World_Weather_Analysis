# %%
# Importing dependencies
import pandas as pd
import numpy as np
import random
import requests
import timeit
from citipy import citipy
from datetime import datetime
import gmaps

# %%
#Creating a set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#Packing each pair of lats and lngs into a tuple
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Adding the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Creating a list for holding the cities.
cities = []
# Identifying the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Printing the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Importing the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Creating an empty list to hold the weather data.
city_data = []

# Creating counters.
record_count = 1
set_count = 1

# %%
# Looping through all the cities in the list.
for i, city in enumerate(cities):

    # Grouping cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Creating endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Loging the URL, record, and setting numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Adding 1 to the record count.
    record_count += 1

    # Running an API request for each of the cities.
    try:
        # Parsing the JSON and retrieving data.
        city_weather = requests.get(city_url).json()
        
        # Parsing out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_weather_descript = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]
        
        

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_descript
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicating that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | miasskoye
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | la ronge
# Processing Record 8 of Set 1 | iqaluit
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | bambous virieux
# Processing Record 12 of Set 1 | hunchun
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | ahipara
# Processing Record 15 of Set 1 | north bend
# Processing Record 16 of Set 1 | cherskiy
# Processing Record 17 of Set 1 | moerai
# Processing Record 18 of Set 1 | manaure
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | tramandai
# Processing Record 21 of Set 1 | puerto escondido
# Processing Record 22 of Set 1 | klaksvik
# Processing Record 23 of Set 1 | cabo san lucas
# Processing Record 24 of Set 1 | bat khela
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 1 | miraflores
# Processing Record 28 of Set 1 | pevek
# Processing Record 29 of Set 1 | zhenhai
# Processing Record 30 of Set 1 | provideniya
# Processing Record 31 of Set 1 | chimore
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | sitka
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | norman wells
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | upernavik
# Processing Record 39 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 1 | te anau
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | san juan
# Processing Record 45 of Set 1 | tiksi
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | kalmunai
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | fortuna
# Processing Record 50 of Set 1 | vangaindrano
# Processing Record 1 of Set 2 | katsuura
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | nanakuli
# Processing Record 4 of Set 2 | buraydah
# Processing Record 5 of Set 2 | poya
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | beloha
# Processing Record 8 of Set 2 | tilichiki
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | ust-kan
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | port moresby
# Processing Record 13 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | san andres
# Processing Record 17 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 2 | hervey bay
# Processing Record 19 of Set 2 | ekuvukeni
# Processing Record 20 of Set 2 | bandarbeyla
# Processing Record 21 of Set 2 | oktyabrskiy
# Processing Record 22 of Set 2 | inuvik
# Processing Record 23 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 2 | meulaboh
# Processing Record 25 of Set 2 | mersing
# Processing Record 26 of Set 2 | mopipi
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | koslan
# Processing Record 29 of Set 2 | russell
# Processing Record 30 of Set 2 | selma
# Processing Record 31 of Set 2 | koshurnikovo
# Processing Record 32 of Set 2 | sao filipe
# Processing Record 33 of Set 2 | yar-sale
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | shimoda
# Processing Record 36 of Set 2 | lompoc
# Processing Record 37 of Set 2 | port-gentil
# Processing Record 38 of Set 2 | taoudenni
# Processing Record 39 of Set 2 | dandong
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | la sarre
# Processing Record 42 of Set 2 | ponta do sol
# Processing Record 43 of Set 2 | balabac
# Processing Record 44 of Set 2 | luderitz
# Processing Record 45 of Set 2 | karratha
# Processing Record 46 of Set 2 | tura
# Processing Record 47 of Set 2 | zouxian
# City not found. Skipping...
# Processing Record 48 of Set 2 | nigde
# Processing Record 49 of Set 2 | fukue
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | birjand
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | tautira
# Processing Record 4 of Set 3 | punta arenas
# Processing Record 5 of Set 3 | bustamante
# Processing Record 6 of Set 3 | santa isabel
# Processing Record 7 of Set 3 | kapaa
# Processing Record 8 of Set 3 | atuona
# Processing Record 9 of Set 3 | sola
# Processing Record 10 of Set 3 | sao sebastiao
# Processing Record 11 of Set 3 | srednekolymsk
# Processing Record 12 of Set 3 | nosy varika
# Processing Record 13 of Set 3 | chinchani
# Processing Record 14 of Set 3 | husavik
# Processing Record 15 of Set 3 | longyearbyen
# Processing Record 16 of Set 3 | broken hill
# Processing Record 17 of Set 3 | avera
# Processing Record 18 of Set 3 | eyl
# Processing Record 19 of Set 3 | port hardy
# Processing Record 20 of Set 3 | yen bai
# Processing Record 21 of Set 3 | tasiilaq
# Processing Record 22 of Set 3 | walvis bay
# Processing Record 23 of Set 3 | taloqan
# Processing Record 24 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 26 of Set 3 | bredasdorp
# Processing Record 27 of Set 3 | hermanus
# Processing Record 28 of Set 3 | kokstad
# Processing Record 29 of Set 3 | port blair
# Processing Record 30 of Set 3 | saint anthony
# Processing Record 31 of Set 3 | zykovo
# Processing Record 32 of Set 3 | saskylakh
# Processing Record 33 of Set 3 | saldanha
# Processing Record 34 of Set 3 | nexo
# Processing Record 35 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 3 | abalak
# Processing Record 37 of Set 3 | mugur-aksy
# Processing Record 38 of Set 3 | ust-nera
# Processing Record 39 of Set 3 | kahului
# Processing Record 40 of Set 3 | tuktoyaktuk
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | necochea
# Processing Record 43 of Set 3 | payo
# Processing Record 44 of Set 3 | matagami
# Processing Record 45 of Set 3 | aklavik
# Processing Record 46 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 3 | den helder
# Processing Record 48 of Set 3 | hami
# Processing Record 49 of Set 3 | nishihara
# Processing Record 50 of Set 3 | silver city
# Processing Record 1 of Set 4 | sergeyevka
# Processing Record 2 of Set 4 | dikson
# Processing Record 3 of Set 4 | barrow
# Processing Record 4 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 5 of Set 4 | nyurba
# Processing Record 6 of Set 4 | abha
# Processing Record 7 of Set 4 | arvi
# Processing Record 8 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 4 | abnub
# Processing Record 10 of Set 4 | ancud
# Processing Record 11 of Set 4 | mananara
# Processing Record 12 of Set 4 | margate
# Processing Record 13 of Set 4 | esperance
# Processing Record 14 of Set 4 | dudinka
# Processing Record 15 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 4 | qaanaaq
# Processing Record 17 of Set 4 | asayita
# City not found. Skipping...
# Processing Record 18 of Set 4 | mayumba
# Processing Record 19 of Set 4 | nanortalik
# Processing Record 20 of Set 4 | kruisfontein
# Processing Record 21 of Set 4 | kirakira
# Processing Record 22 of Set 4 | arlit
# Processing Record 23 of Set 4 | batagay-alyta
# Processing Record 24 of Set 4 | piryion
# City not found. Skipping...
# Processing Record 25 of Set 4 | sisimiut
# Processing Record 26 of Set 4 | kaduna
# Processing Record 27 of Set 4 | hasaki
# Processing Record 28 of Set 4 | fairbanks
# Processing Record 29 of Set 4 | ulladulla
# Processing Record 30 of Set 4 | goundam
# Processing Record 31 of Set 4 | tocopilla
# Processing Record 32 of Set 4 | keti bandar
# Processing Record 33 of Set 4 | constitucion
# Processing Record 34 of Set 4 | kuzino
# Processing Record 35 of Set 4 | islamkot
# Processing Record 36 of Set 4 | agha jari
# City not found. Skipping...
# Processing Record 37 of Set 4 | pacific grove
# Processing Record 38 of Set 4 | wanning
# Processing Record 39 of Set 4 | alice springs
# Processing Record 40 of Set 4 | namatanai
# Processing Record 41 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 42 of Set 4 | wajima
# Processing Record 43 of Set 4 | ribeira grande
# Processing Record 44 of Set 4 | bubaque
# Processing Record 45 of Set 4 | vardo
# Processing Record 46 of Set 4 | oksfjord
# Processing Record 47 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 4 | hadrut
# Processing Record 49 of Set 4 | tremedal
# Processing Record 50 of Set 4 | kaitangata
# Processing Record 1 of Set 5 | toora-khem
# Processing Record 2 of Set 5 | henties bay
# Processing Record 3 of Set 5 | lom sak
# Processing Record 4 of Set 5 | dicabisagan
# Processing Record 5 of Set 5 | surt
# Processing Record 6 of Set 5 | bac lieu
# Processing Record 7 of Set 5 | freilassing
# Processing Record 8 of Set 5 | gandzak
# Processing Record 9 of Set 5 | mareeba
# Processing Record 10 of Set 5 | nambutalai
# Processing Record 11 of Set 5 | itoman
# Processing Record 12 of Set 5 | codrington
# Processing Record 13 of Set 5 | skagen
# Processing Record 14 of Set 5 | khatanga
# Processing Record 15 of Set 5 | tessalit
# Processing Record 16 of Set 5 | muros
# Processing Record 17 of Set 5 | kodiak
# Processing Record 18 of Set 5 | coquimbo
# Processing Record 19 of Set 5 | leningradskiy
# Processing Record 20 of Set 5 | novyy yarychiv
# Processing Record 21 of Set 5 | erzin
# Processing Record 22 of Set 5 | puerto del rosario
# Processing Record 23 of Set 5 | ghanzi
# Processing Record 24 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 5 | ola
# Processing Record 26 of Set 5 | elbistan
# Processing Record 27 of Set 5 | nouadhibou
# Processing Record 28 of Set 5 | chokurdakh
# Processing Record 29 of Set 5 | bull savanna
# Processing Record 30 of Set 5 | lorengau
# Processing Record 31 of Set 5 | airai
# Processing Record 32 of Set 5 | college
# Processing Record 33 of Set 5 | lincoln
# Processing Record 34 of Set 5 | victoria
# Processing Record 35 of Set 5 | soure
# Processing Record 36 of Set 5 | beroroha
# Processing Record 37 of Set 5 | elk city
# Processing Record 38 of Set 5 | vila velha
# Processing Record 39 of Set 5 | padang
# Processing Record 40 of Set 5 | saint-francois
# Processing Record 41 of Set 5 | san cristobal
# Processing Record 42 of Set 5 | verkhoyansk
# Processing Record 43 of Set 5 | comodoro rivadavia
# Processing Record 44 of Set 5 | qaqortoq
# Processing Record 45 of Set 5 | rawson
# Processing Record 46 of Set 5 | sahuaripa
# Processing Record 47 of Set 5 | umarizal
# Processing Record 48 of Set 5 | fort nelson
# Processing Record 49 of Set 5 | redmond
# Processing Record 50 of Set 5 | adrar
# Processing Record 1 of Set 6 | luanda
# Processing Record 2 of Set 6 | santiago del estero
# Processing Record 3 of Set 6 | nome
# Processing Record 4 of Set 6 | san jose
# Processing Record 5 of Set 6 | campbell river
# Processing Record 6 of Set 6 | paka
# Processing Record 7 of Set 6 | beringovskiy
# Processing Record 8 of Set 6 | cananeia
# Processing Record 9 of Set 6 | puerto carreno
# Processing Record 10 of Set 6 | hobart
# Processing Record 11 of Set 6 | tavda
# Processing Record 12 of Set 6 | guerrero negro
# Processing Record 13 of Set 6 | valenza
# Processing Record 14 of Set 6 | kavaratti
# Processing Record 15 of Set 6 | tres lagoas
# Processing Record 16 of Set 6 | tadine
# Processing Record 17 of Set 6 | buinsk
# Processing Record 18 of Set 6 | kismayo
# Processing Record 19 of Set 6 | maneadero
# Processing Record 20 of Set 6 | kavieng
# Processing Record 21 of Set 6 | lebu
# Processing Record 22 of Set 6 | hofn
# Processing Record 23 of Set 6 | faya
# Processing Record 24 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 6 | seoul
# Processing Record 26 of Set 6 | potchefstroom
# Processing Record 27 of Set 6 | anadyr
# Processing Record 28 of Set 6 | bethel
# Processing Record 29 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 6 | manyana
# Processing Record 31 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 32 of Set 6 | piacabucu
# Processing Record 33 of Set 6 | san lorenzo
# Processing Record 34 of Set 6 | ballina
# Processing Record 35 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 6 | kadyy
# Processing Record 37 of Set 6 | pisco
# Processing Record 38 of Set 6 | bengkulu
# Processing Record 39 of Set 6 | roald
# Processing Record 40 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 6 | novikovo
# Processing Record 42 of Set 6 | bosaso
# Processing Record 43 of Set 6 | tual
# Processing Record 44 of Set 6 | alofi
# Processing Record 45 of Set 6 | vestmanna
# Processing Record 46 of Set 6 | shelburne
# Processing Record 47 of Set 6 | rio gallegos
# Processing Record 48 of Set 6 | impfondo
# Processing Record 49 of Set 6 | isangel
# Processing Record 50 of Set 6 | severo-kurilsk
# Processing Record 1 of Set 7 | ingraj bazar
# Processing Record 2 of Set 7 | povenets
# Processing Record 3 of Set 7 | santa quiteria
# Processing Record 4 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 7 | mahebourg
# Processing Record 6 of Set 7 | moose factory
# Processing Record 7 of Set 7 | agadir
# Processing Record 8 of Set 7 | volchansk
# Processing Record 9 of Set 7 | panalingaan
# Processing Record 10 of Set 7 | san patricio
# Processing Record 11 of Set 7 | altay
# Processing Record 12 of Set 7 | ostersund
# Processing Record 13 of Set 7 | diego de almagro
# Processing Record 14 of Set 7 | george
# Processing Record 15 of Set 7 | hovd
# Processing Record 16 of Set 7 | blackpool
# Processing Record 17 of Set 7 | komsomolskiy
# Processing Record 18 of Set 7 | westport
# Processing Record 19 of Set 7 | tuatapere
# Processing Record 20 of Set 7 | itarantim
# Processing Record 21 of Set 7 | vestmannaeyjar
# Processing Record 22 of Set 7 | pleasantville
# Processing Record 23 of Set 7 | coihaique
# Processing Record 24 of Set 7 | thinadhoo
# Processing Record 25 of Set 7 | ladario
# Processing Record 26 of Set 7 | kashary
# Processing Record 27 of Set 7 | yulara
# Processing Record 28 of Set 7 | manchester
# Processing Record 29 of Set 7 | touros
# Processing Record 30 of Set 7 | jumla
# Processing Record 31 of Set 7 | marystown
# Processing Record 32 of Set 7 | cizre
# Processing Record 33 of Set 7 | killybegs
# Processing Record 34 of Set 7 | nemuro
# Processing Record 35 of Set 7 | vanavara
# Processing Record 36 of Set 7 | cam ranh
# Processing Record 37 of Set 7 | harper
# Processing Record 38 of Set 7 | barcelos
# Processing Record 39 of Set 7 | fuling
# Processing Record 40 of Set 7 | benedita
# Processing Record 41 of Set 7 | byron bay
# Processing Record 42 of Set 7 | myitkyina
# Processing Record 43 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 7 | cidreira
# Processing Record 46 of Set 7 | balclutha
# Processing Record 47 of Set 7 | borlange
# City not found. Skipping...
# Processing Record 48 of Set 7 | dingle
# Processing Record 49 of Set 7 | trairi
# Processing Record 50 of Set 7 | egvekinot
# Processing Record 1 of Set 8 | mehran
# Processing Record 2 of Set 8 | natal
# Processing Record 3 of Set 8 | sungaipenuh
# Processing Record 4 of Set 8 | haines junction
# Processing Record 5 of Set 8 | gremyachinsk
# Processing Record 6 of Set 8 | lichtenburg
# Processing Record 7 of Set 8 | yerofey pavlovich
# Processing Record 8 of Set 8 | urucara
# Processing Record 9 of Set 8 | kitob
# Processing Record 10 of Set 8 | shirokiy
# Processing Record 11 of Set 8 | tulum
# Processing Record 12 of Set 8 | sao joao da barra
# Processing Record 13 of Set 8 | kashmor
# Processing Record 14 of Set 8 | riyadh
# Processing Record 15 of Set 8 | saint-augustin
# Processing Record 16 of Set 8 | idah
# Processing Record 17 of Set 8 | mingshui
# Processing Record 18 of Set 8 | yemelyanovo
# Processing Record 19 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 8 | tiarei
# Processing Record 21 of Set 8 | acapulco
# Processing Record 22 of Set 8 | qarqin
# Processing Record 23 of Set 8 | oxford
# Processing Record 24 of Set 8 | homer
# Processing Record 25 of Set 8 | hirara
# Processing Record 26 of Set 8 | lady lake
# Processing Record 27 of Set 8 | ardistan
# City not found. Skipping...
# Processing Record 28 of Set 8 | slonim
# Processing Record 29 of Set 8 | lagoa
# Processing Record 30 of Set 8 | mount isa
# Processing Record 31 of Set 8 | richards bay
# Processing Record 32 of Set 8 | hastings
# Processing Record 33 of Set 8 | pochutla
# Processing Record 34 of Set 8 | tommot
# Processing Record 35 of Set 8 | paita
# Processing Record 36 of Set 8 | goderich
# Processing Record 37 of Set 8 | shieli
# Processing Record 38 of Set 8 | manavalakurichi
# Processing Record 39 of Set 8 | la asuncion
# Processing Record 40 of Set 8 | flin flon
# Processing Record 41 of Set 8 | helmsdale
# Processing Record 42 of Set 8 | ixtapa
# Processing Record 43 of Set 8 | sorland
# Processing Record 44 of Set 8 | havre-saint-pierre
# Processing Record 45 of Set 8 | makhinjauri
# Processing Record 46 of Set 8 | omboue
# Processing Record 47 of Set 8 | viru
# Processing Record 48 of Set 8 | geraldton
# Processing Record 49 of Set 8 | laguna
# Processing Record 50 of Set 8 | saint george
# Processing Record 1 of Set 9 | narsaq
# Processing Record 2 of Set 9 | maragogi
# Processing Record 3 of Set 9 | lata
# Processing Record 4 of Set 9 | coruripe
# Processing Record 5 of Set 9 | santa maria del oro
# Processing Record 6 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 7 of Set 9 | la garriga
# Processing Record 8 of Set 9 | neuquen
# Processing Record 9 of Set 9 | road town
# Processing Record 10 of Set 9 | kathu
# Processing Record 11 of Set 9 | sobolevo
# Processing Record 12 of Set 9 | guararapes
# Processing Record 13 of Set 9 | sesheke
# Processing Record 14 of Set 9 | beyneu
# Processing Record 15 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 16 of Set 9 | itarema
# Processing Record 17 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 18 of Set 9 | beipiao
# Processing Record 19 of Set 9 | flinders
# Processing Record 20 of Set 9 | dalvik
# Processing Record 21 of Set 9 | waipawa
# Processing Record 22 of Set 9 | zunyi
# Processing Record 23 of Set 9 | baton rouge
# Processing Record 24 of Set 9 | malakal
# Processing Record 25 of Set 9 | luba
# Processing Record 26 of Set 9 | kamenka
# Processing Record 27 of Set 9 | cabedelo
# Processing Record 28 of Set 9 | mrakovo
# Processing Record 29 of Set 9 | cordoba
# Processing Record 30 of Set 9 | evensk
# Processing Record 31 of Set 9 | marsa matruh
# Processing Record 32 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 9 | mehamn
# Processing Record 34 of Set 9 | san quintin
# Processing Record 35 of Set 9 | makueni
# Processing Record 36 of Set 9 | makakilo city
# Processing Record 37 of Set 9 | carros
# Processing Record 38 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 9 | antofagasta
# Processing Record 40 of Set 9 | grand gaube
# Processing Record 41 of Set 9 | rincon
# Processing Record 42 of Set 9 | souillac
# Processing Record 43 of Set 9 | paidha
# Processing Record 44 of Set 9 | marrakesh
# Processing Record 45 of Set 9 | xingyi
# Processing Record 46 of Set 9 | buala
# Processing Record 47 of Set 9 | namibe
# Processing Record 48 of Set 9 | uniara
# Processing Record 49 of Set 9 | hohhot
# Processing Record 50 of Set 9 | ratnagiri
# Processing Record 1 of Set 10 | sambava
# Processing Record 2 of Set 10 | lingao
# Processing Record 3 of Set 10 | kushmurun
# Processing Record 4 of Set 10 | nuuk
# Processing Record 5 of Set 10 | batemans bay
# Processing Record 6 of Set 10 | gat
# Processing Record 7 of Set 10 | svetlyy
# Processing Record 8 of Set 10 | phan thiet
# Processing Record 9 of Set 10 | kawalu
# Processing Record 10 of Set 10 | salalah
# Processing Record 11 of Set 10 | abaza
# Processing Record 12 of Set 10 | roswell
# Processing Record 13 of Set 10 | ningan
# City not found. Skipping...
# Processing Record 14 of Set 10 | turayf
# Processing Record 15 of Set 10 | mandera
# Processing Record 16 of Set 10 | emba
# Processing Record 17 of Set 10 | khudumelapye
# Processing Record 18 of Set 10 | kungurtug
# Processing Record 19 of Set 10 | opuwo
# Processing Record 20 of Set 10 | ngunguru
# Processing Record 21 of Set 10 | encruzilhada
# Processing Record 22 of Set 10 | pobe
# Processing Record 23 of Set 10 | hvide sande
# Processing Record 24 of Set 10 | mahibadhoo
# Processing Record 25 of Set 10 | khorramshahr
# Processing Record 26 of Set 10 | brae
# Processing Record 27 of Set 10 | valdivia
# Processing Record 28 of Set 10 | predivinsk
# Processing Record 29 of Set 10 | asau
# Processing Record 30 of Set 10 | nantucket
# Processing Record 31 of Set 10 | lavrentiya
# Processing Record 32 of Set 10 | labuhan
# Processing Record 33 of Set 10 | chuy
# Processing Record 34 of Set 10 | villa carlos paz
# Processing Record 35 of Set 10 | mecca
# Processing Record 36 of Set 10 | panzhihua
# Processing Record 37 of Set 10 | vinces
# Processing Record 38 of Set 10 | hamilton
# Processing Record 39 of Set 10 | winsum
# Processing Record 40 of Set 10 | faanui
# Processing Record 41 of Set 10 | baymak
# Processing Record 42 of Set 10 | kemin
# Processing Record 43 of Set 10 | ust-tsilma
# Processing Record 44 of Set 10 | micheweni
# Processing Record 45 of Set 10 | tarancon
# Processing Record 46 of Set 10 | curup
# Processing Record 47 of Set 10 | carutapera
# Processing Record 48 of Set 10 | surgut
# Processing Record 49 of Set 10 | karonga
# Processing Record 50 of Set 10 | diffa
# Processing Record 1 of Set 11 | mishkino
# Processing Record 2 of Set 11 | broome
# Processing Record 3 of Set 11 | paranaiba
# Processing Record 4 of Set 11 | popondetta
# Processing Record 5 of Set 11 | sabha
# Processing Record 6 of Set 11 | port shepstone
# Processing Record 7 of Set 11 | catia la mar
# Processing Record 8 of Set 11 | pemangkat
# Processing Record 9 of Set 11 | weligama
# Processing Record 10 of Set 11 | qeshm
# Processing Record 11 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 11 | mega
# Processing Record 13 of Set 11 | maryville
# Processing Record 14 of Set 11 | mount gambier
# Processing Record 15 of Set 11 | mayo
# Processing Record 16 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 11 | vilhena
# Processing Record 18 of Set 11 | baculin
# Processing Record 19 of Set 11 | tinaquillo
# Processing Record 20 of Set 11 | pandan
# Processing Record 21 of Set 11 | rosarito
# Processing Record 22 of Set 11 | thabazimbi
# Processing Record 23 of Set 11 | los llanos de aridane
# Processing Record 24 of Set 11 | grindavik
# Processing Record 25 of Set 11 | talnakh
# Processing Record 26 of Set 11 | vilyuysk
# Processing Record 27 of Set 11 | bulgan
# Processing Record 28 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 29 of Set 11 | mitsamiouli
# Processing Record 30 of Set 11 | senneterre
# Processing Record 31 of Set 11 | tartagal
# Processing Record 32 of Set 11 | cap malheureux
# Processing Record 33 of Set 11 | bay roberts
# Processing Record 34 of Set 11 | carbonia
# Processing Record 35 of Set 11 | araouane
# Processing Record 36 of Set 11 | sinnamary
# Processing Record 37 of Set 11 | atherton
# Processing Record 38 of Set 11 | dillon
# Processing Record 39 of Set 11 | bagan
# Processing Record 40 of Set 11 | adre
# Processing Record 41 of Set 11 | oyama
# Processing Record 42 of Set 11 | inirida
# Processing Record 43 of Set 11 | zhangye
# Processing Record 44 of Set 11 | sanchor
# Processing Record 45 of Set 11 | nizhneudinsk
# Processing Record 46 of Set 11 | deputatskiy
# Processing Record 47 of Set 11 | camana
# Processing Record 48 of Set 11 | cairns
# Processing Record 49 of Set 11 | lasa
# Processing Record 50 of Set 11 | bereda
# Processing Record 1 of Set 12 | yurginskoye
# Processing Record 2 of Set 12 | dawei
# Processing Record 3 of Set 12 | sur
# Processing Record 4 of Set 12 | benjamin constant
# Processing Record 5 of Set 12 | muskegon
# Processing Record 6 of Set 12 | ketchikan
# Processing Record 7 of Set 12 | usinsk
# Processing Record 8 of Set 12 | okha
# Processing Record 9 of Set 12 | witu
# Processing Record 10 of Set 12 | sunel
# Processing Record 11 of Set 12 | honiara
# Processing Record 12 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 12 | jutiapa
# Processing Record 14 of Set 12 | cortez
# Processing Record 15 of Set 12 | khasan
# Processing Record 16 of Set 12 | mogadishu
# Processing Record 17 of Set 12 | ambovombe
# Processing Record 18 of Set 12 | lang son
# Processing Record 19 of Set 12 | strezhevoy
# Processing Record 20 of Set 12 | vila
# Processing Record 21 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 22 of Set 12 | alto araguaia
# Processing Record 23 of Set 12 | bryan
# Processing Record 24 of Set 12 | portland
# Processing Record 25 of Set 12 | new kensington
# Processing Record 26 of Set 12 | ternovka
# Processing Record 27 of Set 12 | lazaro cardenas
# Processing Record 28 of Set 12 | clonakilty
# Processing Record 29 of Set 12 | pervomayskoye
# Processing Record 30 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 12 | shache
# Processing Record 32 of Set 12 | sao felix do xingu
# Processing Record 33 of Set 12 | abu kamal
# Processing Record 34 of Set 12 | nagato
# Processing Record 35 of Set 12 | igarape-miri
# City not found. Skipping...
# Processing Record 36 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 12 | albox
# Processing Record 38 of Set 12 | clyde river
# Processing Record 39 of Set 12 | scalloway
# City not found. Skipping...
# Processing Record 40 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 12 | marawi
# Processing Record 42 of Set 12 | mortka
# Processing Record 43 of Set 12 | pousat
# City not found. Skipping...
# Processing Record 44 of Set 12 | cedar city
# Processing Record 45 of Set 12 | lambarene
# Processing Record 46 of Set 12 | sawakin
# Processing Record 47 of Set 12 | kintampo
# Processing Record 48 of Set 12 | gambela
# Processing Record 49 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 12 | north myrtle beach
# Processing Record 1 of Set 13 | olafsvik
# Processing Record 2 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 13 | taonan
# Processing Record 4 of Set 13 | chugunash
# City not found. Skipping...
# Processing Record 5 of Set 13 | carballo
# Processing Record 6 of Set 13 | srandakan
# Processing Record 7 of Set 13 | khuzhir
# Processing Record 8 of Set 13 | boffa
# Processing Record 9 of Set 13 | beatrice
# Processing Record 10 of Set 13 | wilmington
# Processing Record 11 of Set 13 | san borja
# Processing Record 12 of Set 13 | zachagansk
# City not found. Skipping...
# Processing Record 13 of Set 13 | krasnyy
# Processing Record 14 of Set 13 | tomatlan
# Processing Record 15 of Set 13 | juegang
# Processing Record 16 of Set 13 | trindade
# Processing Record 17 of Set 13 | bilma
# Processing Record 18 of Set 13 | gejiu
# Processing Record 19 of Set 13 | puerto boyaca
# Processing Record 20 of Set 13 | dukat
# Processing Record 21 of Set 13 | ostrovnoy
# Processing Record 22 of Set 13 | urupes
# Processing Record 23 of Set 13 | selfoss
# Processing Record 24 of Set 13 | praia da vitoria
# Processing Record 25 of Set 13 | amapa
# Processing Record 26 of Set 13 | sosnogorsk
# Processing Record 27 of Set 13 | takaka
# Processing Record 28 of Set 13 | kieta
# Processing Record 29 of Set 13 | aquiraz
# Processing Record 30 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 13 | ust-maya
# Processing Record 32 of Set 13 | bontang
# Processing Record 33 of Set 13 | guhagar
# Processing Record 34 of Set 13 | deoranian
# Processing Record 35 of Set 13 | zhigansk
# Processing Record 36 of Set 13 | tiruchchendur
# Processing Record 37 of Set 13 | ifakara
# Processing Record 38 of Set 13 | kleive
# Processing Record 39 of Set 13 | melekhovskaya
# City not found. Skipping...
# Processing Record 40 of Set 13 | colares
# Processing Record 41 of Set 13 | shingu
# Processing Record 42 of Set 13 | san gavino monreale
# Processing Record 43 of Set 13 | giyani
# Processing Record 44 of Set 13 | boralday
# Processing Record 45 of Set 13 | verkhnevilyuysk
# Processing Record 46 of Set 13 | coachella
# Processing Record 47 of Set 13 | hokitika
# Processing Record 48 of Set 13 | zabid
# Processing Record 49 of Set 13 | bilibino
# Processing Record 50 of Set 13 | newcastle
# Processing Record 1 of Set 14 | tiznit
# Processing Record 2 of Set 14 | lerwick
# Processing Record 3 of Set 14 | nuristan
# Processing Record 4 of Set 14 | havelock
# Processing Record 5 of Set 14 | yaan
# Processing Record 6 of Set 14 | ilinskoye-khovanskoye
# Processing Record 7 of Set 14 | bonthe
# Processing Record 8 of Set 14 | west lafayette
# Processing Record 9 of Set 14 | camargo
# Processing Record 10 of Set 14 | locri
# Processing Record 11 of Set 14 | sampit
# Processing Record 12 of Set 14 | laguna de perlas
# Processing Record 13 of Set 14 | burica
# City not found. Skipping...
# Processing Record 14 of Set 14 | fare
# Processing Record 15 of Set 14 | klyuchi
# Processing Record 16 of Set 14 | kang
# Processing Record 17 of Set 14 | chapais
# Processing Record 18 of Set 14 | launceston
# Processing Record 19 of Set 14 | vanimo
# Processing Record 20 of Set 14 | pahrump
# Processing Record 21 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 22 of Set 14 | menongue
# Processing Record 23 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 14 | gimli
# Processing Record 25 of Set 14 | goure
# Processing Record 26 of Set 14 | perelyub
# Processing Record 27 of Set 14 | sibolga
# Processing Record 28 of Set 14 | nioki
# Processing Record 29 of Set 14 | les cayes
# Processing Record 30 of Set 14 | lusambo
# Processing Record 31 of Set 14 | paragould
# Processing Record 32 of Set 14 | oriximina
# Processing Record 33 of Set 14 | manokwari
# Processing Record 34 of Set 14 | mirnyy
# Processing Record 35 of Set 14 | beidao
# Processing Record 36 of Set 14 | phangnga
# Processing Record 37 of Set 14 | ponoka
# Processing Record 38 of Set 14 | sarlat-la-caneda
# Processing Record 39 of Set 14 | port-cartier
# Processing Record 40 of Set 14 | kochi
# Processing Record 41 of Set 14 | ouadda
# Processing Record 42 of Set 14 | lianzhou
# Processing Record 43 of Set 14 | caravelas
# Processing Record 44 of Set 14 | nokia
# Processing Record 45 of Set 14 | zarubino
# Processing Record 46 of Set 14 | leiyang
# Processing Record 47 of Set 14 | mbalmayo
# Processing Record 48 of Set 14 | sunrise manor
# Processing Record 49 of Set 14 | vung tau
# Processing Record 50 of Set 14 | hachinohe
# Processing Record 1 of Set 15 | zalesovo
# Processing Record 2 of Set 15 | koulikoro
# Processing Record 3 of Set 15 | vengurla
# Processing Record 4 of Set 15 | buk
# Processing Record 5 of Set 15 | san joaquin
# Processing Record 6 of Set 15 | areosa
# Processing Record 7 of Set 15 | ambunti
# Processing Record 8 of Set 15 | bagli
# Processing Record 9 of Set 15 | petrovsk
# Processing Record 10 of Set 15 | pangnirtung
# Processing Record 11 of Set 15 | prince rupert
# Processing Record 12 of Set 15 | coahuayana
# Processing Record 13 of Set 15 | krasnoselkup
# Processing Record 14 of Set 15 | sladkovo
# Processing Record 15 of Set 15 | obera
# Processing Record 16 of Set 15 | kodino
# Processing Record 17 of Set 15 | seymchan
# Processing Record 18 of Set 15 | gravdal
# Processing Record 19 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 15 | puerto triunfo
# Processing Record 21 of Set 15 | mayya
# Processing Record 22 of Set 15 | novozavidovskiy
# Processing Record 23 of Set 15 | onguday
# Processing Record 24 of Set 15 | naze
# Processing Record 25 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 26 of Set 15 | barabai
# Processing Record 27 of Set 15 | zelenoborskiy
# Processing Record 28 of Set 15 | tandalti
# Processing Record 29 of Set 15 | nyzy
# Processing Record 30 of Set 15 | prabumulih
# Processing Record 31 of Set 15 | nova bystrice
# Processing Record 32 of Set 15 | ust-kuyga
# Processing Record 33 of Set 15 | esso
# Processing Record 34 of Set 15 | marsh harbour
# Processing Record 35 of Set 15 | auki
# Processing Record 36 of Set 15 | kaabong
# Processing Record 37 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 38 of Set 15 | christchurch
# Processing Record 39 of Set 15 | ambilobe
# Processing Record 40 of Set 15 | thung song
# Processing Record 41 of Set 15 | tubuala
# Processing Record 42 of Set 15 | ulaangom
# Processing Record 43 of Set 15 | kassala
# Processing Record 44 of Set 15 | waw
# Processing Record 45 of Set 15 | yermakovskoye
# Processing Record 46 of Set 15 | benxi
# Processing Record 47 of Set 15 | elko
# Processing Record 48 of Set 15 | aksu
# Processing Record 49 of Set 15 | nhamunda
# Processing Record 50 of Set 15 | presidente medici
# Processing Record 1 of Set 16 | aksarka
# Processing Record 2 of Set 16 | zharkent
# Processing Record 3 of Set 16 | semey
# Processing Record 4 of Set 16 | turkistan
# Processing Record 5 of Set 16 | poum
# Processing Record 6 of Set 16 | half moon bay
# Processing Record 7 of Set 16 | carambei
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Converting the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Miasskoye      RU  55.2784   61.8905     -4.00        59          40
# 1  Georgetown      MY   5.4112  100.3354     82.00        78          20
# 2    Thompson      CA  55.7435  -97.8558    -27.40        68          75
# 3   Jamestown      US  42.0970  -79.2353     12.99        72          90
# 4      Avarua      CK -21.2078 -159.7750     84.20        79          40
#
#    Wind Speed Current Description
# 0       13.42          light snow
# 1        2.30          few clouds
# 2       14.97                snow
# 3       10.36          light snow
# 4       10.36          light rain

# %%
# Creating the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Exporting the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
